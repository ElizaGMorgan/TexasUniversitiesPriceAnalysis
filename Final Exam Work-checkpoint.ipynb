# %%
# Due date: Mar 23, 11:59 pm.
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
df = pd.read_csv("THECB Prices 2009-2020.csv")
df
# Out:
#        Institution Type / Institution  Fice Code  \
# 0             Angelo State University       3541
# 1                    Lamar University       3581
# 2         Midwestern State University       3592
# 3         Prairie View A&M University       3630
# 4        Sam Houston State University       3606
# ..                                ...        ...
# 954  University of Mary Hardin-Baylor       3588
# 955          University of St. Thomas       3654
# 956  University of the Incarnate Word       3578
# 957        Wayland Baptist University       3663
# 958                     Wiley College       3669
#
#      Average of Resident Tuition and Fees  \
# 0                                    5111
# 1                                    6014
# 2                                    6237
# 3                                    6118
# 4                                    5910
# ..                                    ...
# 954                                 30750
# ...

# %%
#I know I could have used loops for this, but copy pasting required a lot less thinking
private2008 = (df['Year'] == 2008) & (df['Public / Private'] == 'Private')
private2009 = (df['Year'] == 2009) & (df['Public / Private'] == 'Private')
private2010 = (df['Year'] == 2010) & (df['Public / Private'] == 'Private')
private2011 = (df['Year'] == 2011) & (df['Public / Private'] == 'Private')
private2012 = (df['Year'] == 2012) & (df['Public / Private'] == 'Private')
private2013 = (df['Year'] == 2013) & (df['Public / Private'] == 'Private')
private2014 = (df['Year'] == 2014) & (df['Public / Private'] == 'Private')
private2015 = (df['Year'] == 2015) & (df['Public / Private'] == 'Private')
private2016 = (df['Year'] == 2016) & (df['Public / Private'] == 'Private')
private2017 = (df['Year'] == 2017) & (df['Public / Private'] == 'Private')
private2018 = (df['Year'] == 2018) & (df['Public / Private'] == 'Private')
private2019 = (df['Year'] == 2019) & (df['Public / Private'] == 'Private')
private2020 = (df['Year'] == 2020) & (df['Public / Private'] == 'Private')

private2008Avg = df[private2008]['Average of Total Resident Costs'].mean()
private2009Avg = df[private2009]['Average of Total Resident Costs'].mean()
private2010Avg = df[private2010]['Average of Total Resident Costs'].mean()
private2011Avg = df[private2011]['Average of Total Resident Costs'].mean()
private2012Avg = df[private2012]['Average of Total Resident Costs'].mean()
private2013Avg = df[private2013]['Average of Total Resident Costs'].mean()
private2014Avg = df[private2014]['Average of Total Resident Costs'].mean()
private2015Avg = df[private2015]['Average of Total Resident Costs'].mean()
private2016Avg = df[private2016]['Average of Total Resident Costs'].mean()
private2017Avg = df[private2017]['Average of Total Resident Costs'].mean()
private2018Avg = df[private2018]['Average of Total Resident Costs'].mean()
private2019Avg = df[private2019]['Average of Total Resident Costs'].mean()
private2020Avg = df[private2020]['Average of Total Resident Costs'].mean()

privatePriceAverage = [private2008Avg, private2009Avg, private2010Avg, private2011Avg, private2012Avg, private2013Avg, private2014Avg, private2015Avg, private2016Avg, private2017Avg, private2018Avg, private2019Avg, private2020Avg]

public2008 = (df['Year'] == 2008) & (df['Public / Private'] == 'Public')
public2009 = (df['Year'] == 2009) & (df['Public / Private'] == 'Public')
public2010 = (df['Year'] == 2010) & (df['Public / Private'] == 'Public')
public2011 = (df['Year'] == 2011) & (df['Public / Private'] == 'Public')
public2012 = (df['Year'] == 2012) & (df['Public / Private'] == 'Public')
public2013 = (df['Year'] == 2013) & (df['Public / Private'] == 'Public')
public2014 = (df['Year'] == 2014) & (df['Public / Private'] == 'Public')
public2015 = (df['Year'] == 2015) & (df['Public / Private'] == 'Public')
public2016 = (df['Year'] == 2016) & (df['Public / Private'] == 'Public')
public2017 = (df['Year'] == 2017) & (df['Public / Private'] == 'Public')
public2018 = (df['Year'] == 2018) & (df['Public / Private'] == 'Public')
public2019 = (df['Year'] == 2019) & (df['Public / Private'] == 'Public')
public2020 = (df['Year'] == 2020) & (df['Public / Private'] == 'Public')

public2008Avg = df[public2008]['Average of Total Resident Costs'].mean()
public2009Avg = df[public2009]['Average of Total Resident Costs'].mean()
public2010Avg = df[public2010]['Average of Total Resident Costs'].mean()
public2011Avg = df[public2011]['Average of Total Resident Costs'].mean()
public2012Avg = df[public2012]['Average of Total Resident Costs'].mean()
public2013Avg = df[public2013]['Average of Total Resident Costs'].mean()
public2014Avg = df[public2014]['Average of Total Resident Costs'].mean()
public2015Avg = df[public2015]['Average of Total Resident Costs'].mean()
public2016Avg = df[public2016]['Average of Total Resident Costs'].mean()
public2017Avg = df[public2017]['Average of Total Resident Costs'].mean()
public2018Avg = df[public2018]['Average of Total Resident Costs'].mean()
public2019Avg = df[public2019]['Average of Total Resident Costs'].mean()
public2020Avg = df[public2020]['Average of Total Resident Costs'].mean()


publicPriceAverage = [public2008Avg, public2009Avg, public2010Avg, public2011Avg, public2012Avg, public2013Avg, public2014Avg, public2015Avg, public2016Avg, public2017Avg, public2018Avg, public2019Avg, public2020Avg,]

years = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
plt.scatter(years, privatePriceAverage, color = 'red')
plt.scatter(years, publicPriceAverage, color = 'green')

plt.ylim(15000, 50000)
plt.show()

# %%
private2008Avg, private2009Avg, private2010Avg
# Out:
# (29858.675675675677, 30129.486486486487, 31206.763157894737)

# %%
plt.scatter(df['Year'], df['Average of Total Resident Costs'], color = 'orange')

# %%
year2008 = (df['Year'] == 2008)
year2009 = (df['Year'] == 2009)
year2010 = (df['Year'] == 2010)
year2011 = (df['Year'] == 2011)
year2012 = (df['Year'] == 2012)
year2013 = (df['Year'] == 2013)
year2014 = (df['Year'] == 2014)
year2015 = (df['Year'] == 2015)
year2016 = (df['Year'] == 2016)
year2017 = (df['Year'] == 2017)
year2018 = (df['Year'] == 2018)
year2019 = (df['Year'] == 2019)
year2020 = (df['Year'] == 2020)
df[year2008].nlargest(2, 'Average of Total Resident Costs')
# Out:
#                      Institution Type / Institution  Fice Code  \
# 64  The College of Saints John Fisher & Thomas More     420352
# 51                                  Rice University       3604
#
#     Average of Resident Tuition and Fees  \
# 64                                 12250
# 51                                 30486
#
#     Average of Non-Resident Tuition and Fees  \
# 64                                     12250
# 51                                     30486
#
#     Average of In-District Tuition and Fees  \
# 64                                        0
# 51                                        0
#
#     Average of Out-of-District Tuition and Fees  \
# 64                                            0
# 51                                            0
#
#     Average of Books and Supplies  Average of Room and Board off-Campus  \
# 64                            650                                 45000
# ...

# %%
#HIGH outlier for 2008 price. Typo on "Average room and board", making it $45,000 instead of $4,500 (deduced from prices for future years)
df.loc[df['Institution Type / Institution'] == 'The College of Saints John Fisher & Thomas More']
# Out:
#                       Institution Type / Institution  Fice Code  \
# 64   The College of Saints John Fisher & Thomas More     420352
# 136  The College of Saints John Fisher & Thomas More     420352
# 212  The College of Saints John Fisher & Thomas More     420352
# 288  The College of Saints John Fisher & Thomas More     420352
# 363  The College of Saints John Fisher & Thomas More     420352
# 438  The College of Saints John Fisher & Thomas More     420352
#
#      Average of Resident Tuition and Fees  \
# 64                                  12250
# 136                                 12490
# 212                                 12800
# 288                                 12800
# 363                                 12800
# 438                                 10000
#
#      Average of Non-Resident Tuition and Fees  \
# 64                                      12250
# 136                                     12490
# 212                                     12800
# ...

# %%
#Fixing the outlier for 2008 created by the typo, changing Average Room and Board to 4500 and Average Total to 20775
#61275 - (45000 - 4500) = 20775
df.iat[64, 7] = 4500
df.iat[64, 10] = 20775
df.loc[df['Institution Type / Institution'] == 'The College of Saints John Fisher & Thomas More']
# Out:
#                       Institution Type / Institution  Fice Code  \
# 64   The College of Saints John Fisher & Thomas More     420352
# 136  The College of Saints John Fisher & Thomas More     420352
# 212  The College of Saints John Fisher & Thomas More     420352
# 288  The College of Saints John Fisher & Thomas More     420352
# 363  The College of Saints John Fisher & Thomas More     420352
# 438  The College of Saints John Fisher & Thomas More     420352
#
#      Average of Resident Tuition and Fees  \
# 64                                  12250
# 136                                 12490
# 212                                 12800
# 288                                 12800
# 363                                 12800
# 438                                 10000
#
#      Average of Non-Resident Tuition and Fees  \
# 64                                      12250
# 136                                     12490
# 212                                     12800
# ...

# %%
df.loc[df['Institution Type / Institution'] == 'Sul Ross State University Rio Grande College']
# Out:
#                    Institution Type / Institution  Fice Code  \
# 7    Sul Ross State University Rio Grande College         20
# 79   Sul Ross State University Rio Grande College         20
# 151  Sul Ross State University Rio Grande College         20
# 227  Sul Ross State University Rio Grande College         20
# 303  Sul Ross State University Rio Grande College         20
# 378  Sul Ross State University Rio Grande College         20
# 453  Sul Ross State University Rio Grande College         20
# 527  Sul Ross State University Rio Grande College         20
# 601  Sul Ross State University Rio Grande College         20
# 674  Sul Ross State University Rio Grande College         20
# 747  Sul Ross State University Rio Grande College         20
# 820  Sul Ross State University Rio Grande College         20
# 893  Sul Ross State University Rio Grande College         20
#
#      Average of Resident Tuition and Fees  \
# 7                                    3456
# ...

# %%
df2009 = df[year2009]
SulRossRoomAndBoard2009 = (df2009['Average of Resident Tuition and Fees'] < 4600) & (df2009['Average of Resident Tuition and Fees'] > 2600)
df2009[SulRossRoomAndBoard2009]
# Out:
#                   Institution Type / Institution  Fice Code  \
# 79  Sul Ross State University Rio Grande College         20
# 87                Texas A&M University-Texarkana      29269
#
#     Average of Resident Tuition and Fees  \
# 79                                  3636
# 87                                  4538
#
#     Average of Non-Resident Tuition and Fees  \
# 79                                     11946
# 87                                     12848
#
#     Average of In-District Tuition and Fees  \
# 79                                        0
# 87                                        0
#
#     Average of Out-of-District Tuition and Fees  \
# 79                                            0
# 87                                            0
#
#     Average of Books and Supplies  Average of Room and Board off-Campus  \
# 79                            569                                     0
# 87                           1160                                  5380
#
# ...

# %%
df2010 = df[year2010]
SulRossRoomAndBoard2010 = (df2010['Average of Resident Tuition and Fees'] < 4800) & (df2010['Average of Resident Tuition and Fees'] > 2800)
df2010[SulRossRoomAndBoard2010]
# Out:
#                    Institution Type / Institution  Fice Code  \
# 151  Sul Ross State University Rio Grande College         20
#
#      Average of Resident Tuition and Fees  \
# 151                                  3786
#
#      Average of Non-Resident Tuition and Fees  \
# 151                                     13086
#
#      Average of In-District Tuition and Fees  \
# 151                                        0
#
#      Average of Out-of-District Tuition and Fees  \
# 151                                            0
#
#      Average of Books and Supplies  Average of Room and Board off-Campus  \
# 151                            597                                     0
#
#      Average of Transportation Off-Campus  \
# 151                                     0
#
#      Average of Personal Expenses Off-Campus  Average of Total Resident Costs  \
# 151                                        0                             4383
#
# ...

# %%
#We were going to average missing values by year based on instituation with similar in-state tuition averages ($1000+-)
#but only one or zero came up, so we decided to drop them
df2008 = df[year2008]
SulRossRoomAndBoard2008 = (df2008['Average of Resident Tuition and Fees'] < 4500) & (df2008['Average of Resident Tuition and Fees'] > 2500)
df2008[SulRossRoomAndBoard2008]
# Out:
#                   Institution Type / Institution  Fice Code  \
# 7   Sul Ross State University Rio Grande College         20
# 15                Texas A&M University-Texarkana      29269
#
#     Average of Resident Tuition and Fees  \
# 7                                   3456
# 15                                  4236
#
#     Average of Non-Resident Tuition and Fees  \
# 7                                      11886
# 15                                     12666
#
#     Average of In-District Tuition and Fees  \
# 7                                         0
# 15                                        0
#
#     Average of Out-of-District Tuition and Fees  \
# 7                                             0
# 15                                            0
#
#     Average of Books and Supplies  Average of Room and Board off-Campus  \
# 7                             555                                     0
# 15                           1160                                  5124
#
# ...

# %%
#Low outlier for 2008-2011, due to not including off campus housing prices, transportation prices, and personal expenses
df.loc[df['Institution Type / Institution'] == 'Amberton University']
# Out:
#     Institution Type / Institution  Fice Code  \
# 183            Amberton University      22594
# 259            Amberton University      22594
# 335            Amberton University      22594
# 410            Amberton University      22594
# 485            Amberton University      22594
# 559            Amberton University      22594
# 632            Amberton University      22594
# 705            Amberton University      22594
# 778            Amberton University      22594
# 851            Amberton University      22594
# 924            Amberton University      22594
#
#      Average of Resident Tuition and Fees  \
# 183                                  7000
# 259                                  7050
# 335                                  7050
# 410                                  7260
# 485                                  7260
# 559                                  7500
# 632                                  7500
# 705                                  7990
# ...

# %%
#Low outlier for 2008-2011, due to not including off campus housing prices, transportation prices, and personal expenses
df.loc[df['Institution Type / Institution'] == 'Sul Ross State University Rio Grande College']
# Out:
#                    Institution Type / Institution  Fice Code  \
# 7    Sul Ross State University Rio Grande College         20
# 79   Sul Ross State University Rio Grande College         20
# 151  Sul Ross State University Rio Grande College         20
# 227  Sul Ross State University Rio Grande College         20
# 303  Sul Ross State University Rio Grande College         20
# 378  Sul Ross State University Rio Grande College         20
# 453  Sul Ross State University Rio Grande College         20
# 527  Sul Ross State University Rio Grande College         20
# 601  Sul Ross State University Rio Grande College         20
# 674  Sul Ross State University Rio Grande College         20
# 747  Sul Ross State University Rio Grande College         20
# 820  Sul Ross State University Rio Grande College         20
# 893  Sul Ross State University Rio Grande College         20
#
#      Average of Resident Tuition and Fees  \
# 7                                    3456
# ...

# %%
#Replacing zeroes with nan so I can use .isnull to find missing data
df = df.replace(0, np.nan)
df.head()
# Out:
#   Institution Type / Institution  Fice Code  \
# 0        Angelo State University       3541
# 1               Lamar University       3581
# 2    Midwestern State University       3592
# 3    Prairie View A&M University       3630
# 4   Sam Houston State University       3606
#
#    Average of Resident Tuition and Fees  \
# 0                                  5111
# 1                                  6014
# 2                                  6237
# 3                                  6118
# 4                                  5910
#
#    Average of Non-Resident Tuition and Fees  \
# 0                                   13541.0
# 1                                   14444.0
# 2                                   14667.0
# 3                                   14458.0
# 4                                   14250.0
#
#    Average of In-District Tuition and Fees  \
# 0                                      NaN
# 1                                      NaN
# ...

# %%
#Due to using 'Average of Total Resident Costs' for our price, we don't worry about missing values in
#'Average of Non-Resident Tuition and Fees', 'Average of In-District Tuition and Fees',
#'Average of Out-of-District Tuition and Fees', 'Average of Total Non Resident Costs',
#'Average of Total In District Costs', 'Average of Total Out of District Costs'
#Leaving us to only worry about columns
#'Average of Books and Supplies', 'Average of Room and Board off-Campus',
#'Average of Transportation Off-Campus', 'Average of Personal Expenses Off-Campus',
df.columns[df.isnull().any()]
# Out:
# Index(['Average of Non-Resident Tuition and Fees',
#        'Average of In-District Tuition and Fees',
#        'Average of Out-of-District Tuition and Fees',
#        'Average of Books and Supplies', 'Average of Room and Board off-Campus',
#        'Average of Transportation Off-Campus',
#        'Average of Personal Expenses Off-Campus',
#        'Average of Total Non Resident Costs',
#        'Average of Total In District Costs',
#        'Average of Total Out of District Costs'],
#       dtype='object')

# %%
#Using the second line, we can see there's 28 missing values, using the first line we can find there are problem colleges
#Who show up multiple times. Amberton University(6), Schreiner University(5), Wiley College(4)
#8 of these are NaN for ALL of the columns we've deemed important with missing values, so we'll drop all of them
df[df['Average of Books and Supplies'].isna()]
#df[df['Average of Books and Supplies'].isna()].count()
# Out:
#                      Institution Type / Institution  Fice Code  \
# 44                      Huston-Tillotson University       3577
# 227    Sul Ross State University Rio Grande College         20
# 259                             Amberton University      22594
# 266                      Houston Baptist University       3576
# 268                     Huston-Tillotson University       3577
# 276                            Schreiner University       3610
# 295                                   Wiley College       3669
# 299                     Prairie View A&M University       3630
# 335                             Amberton University      22594
# 370                                   Wiley College       3669
# 374                     Prairie View A&M University       3630
# 410                             Amberton University      22594
# 426                            Schreiner University       3610
# 427                   Southern Methodist University       3613
# ...

# %%
#15 here, 8 of which overlap with Books and Supplies
df[df['Average of Personal Expenses Off-Campus'].isna()]
#df[df['Average of Personal Expenses Off-Campus'].isna()].count()
# Out:
#                    Institution Type / Institution  Fice Code  \
# 7    Sul Ross State University Rio Grande College         20
# 79   Sul Ross State University Rio Grande College         20
# 151  Sul Ross State University Rio Grande College         20
# 183                           Amberton University      22594
# 227  Sul Ross State University Rio Grande College         20
# 259                           Amberton University      22594
# 335                           Amberton University      22594
# 410                           Amberton University      22594
# 485                           Amberton University      22594
# 559                           Amberton University      22594
# 632                           Amberton University      22594
# 705                           Amberton University      22594
# 778                           Amberton University      22594
# 851                           Amberton University      22594
# ...

# %%
#We decided to just drop any rows with missing values in important columns, which only dropped us 38 entries out of 959
#leaving us with 921 entries
df.dropna(subset=['Average of Books and Supplies', 'Average of Room and Board off-Campus',
'Average of Transportation Off-Campus', 'Average of Personal Expenses Off-Campus'], inplace = True)
df
# Out:
#        Institution Type / Institution  Fice Code  \
# 0             Angelo State University       3541
# 1                    Lamar University       3581
# 2         Midwestern State University       3592
# 3         Prairie View A&M University       3630
# 4        Sam Houston State University       3606
# ..                                ...        ...
# 953              University of Dallas       3651
# 954  University of Mary Hardin-Baylor       3588
# 955          University of St. Thomas       3654
# 956  University of the Incarnate Word       3578
# 957        Wayland Baptist University       3663
#
#      Average of Resident Tuition and Fees  \
# 0                                    5111
# 1                                    6014
# 2                                    6237
# 3                                    6118
# 4                                    5910
# ..                                    ...
# 953                                 44810
# ...

# %%
private2008 = (df['Year'] == 2008) & (df['Public / Private'] == 'Private')
private2009 = (df['Year'] == 2009) & (df['Public / Private'] == 'Private')
private2010 = (df['Year'] == 2010) & (df['Public / Private'] == 'Private')
private2011 = (df['Year'] == 2011) & (df['Public / Private'] == 'Private')
private2012 = (df['Year'] == 2012) & (df['Public / Private'] == 'Private')
private2013 = (df['Year'] == 2013) & (df['Public / Private'] == 'Private')
private2014 = (df['Year'] == 2014) & (df['Public / Private'] == 'Private')
private2015 = (df['Year'] == 2015) & (df['Public / Private'] == 'Private')
private2016 = (df['Year'] == 2016) & (df['Public / Private'] == 'Private')
private2017 = (df['Year'] == 2017) & (df['Public / Private'] == 'Private')
private2018 = (df['Year'] == 2018) & (df['Public / Private'] == 'Private')
private2019 = (df['Year'] == 2019) & (df['Public / Private'] == 'Private')
private2020 = (df['Year'] == 2020) & (df['Public / Private'] == 'Private')

private2008Avg = df[private2008]['Average of Total Resident Costs'].mean()
private2009Avg = df[private2009]['Average of Total Resident Costs'].mean()
private2010Avg = df[private2010]['Average of Total Resident Costs'].mean()
private2011Avg = df[private2011]['Average of Total Resident Costs'].mean()
private2012Avg = df[private2012]['Average of Total Resident Costs'].mean()
private2013Avg = df[private2013]['Average of Total Resident Costs'].mean()
private2014Avg = df[private2014]['Average of Total Resident Costs'].mean()
private2015Avg = df[private2015]['Average of Total Resident Costs'].mean()
private2016Avg = df[private2016]['Average of Total Resident Costs'].mean()
private2017Avg = df[private2017]['Average of Total Resident Costs'].mean()
private2018Avg = df[private2018]['Average of Total Resident Costs'].mean()
private2019Avg = df[private2019]['Average of Total Resident Costs'].mean()
private2020Avg = df[private2020]['Average of Total Resident Costs'].mean()

privatePriceAverage = [private2008Avg, private2009Avg, private2010Avg, private2011Avg, private2012Avg, private2013Avg, private2014Avg, private2015Avg, private2016Avg, private2017Avg, private2018Avg, private2019Avg, private2020Avg]

public2008 = (df['Year'] == 2008) & (df['Public / Private'] == 'Public')
public2009 = (df['Year'] == 2009) & (df['Public / Private'] == 'Public')
public2010 = (df['Year'] == 2010) & (df['Public / Private'] == 'Public')
public2011 = (df['Year'] == 2011) & (df['Public / Private'] == 'Public')
public2012 = (df['Year'] == 2012) & (df['Public / Private'] == 'Public')
public2013 = (df['Year'] == 2013) & (df['Public / Private'] == 'Public')
public2014 = (df['Year'] == 2014) & (df['Public / Private'] == 'Public')
public2015 = (df['Year'] == 2015) & (df['Public / Private'] == 'Public')
public2016 = (df['Year'] == 2016) & (df['Public / Private'] == 'Public')
public2017 = (df['Year'] == 2017) & (df['Public / Private'] == 'Public')
public2018 = (df['Year'] == 2018) & (df['Public / Private'] == 'Public')
public2019 = (df['Year'] == 2019) & (df['Public / Private'] == 'Public')
public2020 = (df['Year'] == 2020) & (df['Public / Private'] == 'Public')

public2008Avg = df[public2008]['Average of Total Resident Costs'].mean()
public2009Avg = df[public2009]['Average of Total Resident Costs'].mean()
public2010Avg = df[public2010]['Average of Total Resident Costs'].mean()
public2011Avg = df[public2011]['Average of Total Resident Costs'].mean()
public2012Avg = df[public2012]['Average of Total Resident Costs'].mean()
public2013Avg = df[public2013]['Average of Total Resident Costs'].mean()
public2014Avg = df[public2014]['Average of Total Resident Costs'].mean()
public2015Avg = df[public2015]['Average of Total Resident Costs'].mean()
public2016Avg = df[public2016]['Average of Total Resident Costs'].mean()
public2017Avg = df[public2017]['Average of Total Resident Costs'].mean()
public2018Avg = df[public2018]['Average of Total Resident Costs'].mean()
public2019Avg = df[public2019]['Average of Total Resident Costs'].mean()
public2020Avg = df[public2020]['Average of Total Resident Costs'].mean()


publicPriceAverage = [public2008Avg, public2009Avg, public2010Avg, public2011Avg, public2012Avg, public2013Avg, public2014Avg, public2015Avg, public2016Avg, public2017Avg, public2018Avg, public2019Avg, public2020Avg,]


years = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
plt.scatter(years, privatePriceAverage, color = 'blue')
plt.scatter(years, publicPriceAverage, color = 'orange')

plt.ylim(15000, 50000)
plt.show()

# %%
private2008Avg, private2009Avg, private2010Avg
# Out:
# (28807.371428571427, 29949.416666666668, 31644.694444444445)

# %%
plt.scatter(df['Year'], df['Average of Total Resident Costs'], color = 'purple')
